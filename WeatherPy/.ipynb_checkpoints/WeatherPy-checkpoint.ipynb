# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 603

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&appid=" + weather_api_key + "&q=" 
    
     # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url + city).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = (city_weather['coord']['lat'])
        city_lng = (city_weather['coord']['lon'])
        city_max_temp = (city_weather['main']['temp_max'])
        city_humidity = (city_weather['main']['humidity'])
        city_clouds = (city_weather['clouds']['all'])
        city_wind = (city_weather['wind']['speed'])
        city_country = (city_weather['sys']['country'])
        city_date = (city_weather['dt'])

    # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

#print("Latitude:", city_lat)
#print("Longitude:", city_lon)
#print("Max Temperature:", city_max_temp)
#print("Humidity:", city_humidity)
#print("Cloudiness:", city_clouds)
#print("Wind Speed:", city_wind)
#print("Country:", city_country)
#print("Date:", city_date)

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | giovinazzo
# Processing Record 3 of Set 1 | tofol
# Processing Record 4 of Set 1 | puerto natales
# Processing Record 5 of Set 1 | karratha
# Processing Record 6 of Set 1 | vanimo
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | port mathurin
# Processing Record 9 of Set 1 | grytviken
# Processing Record 10 of Set 1 | hawaiian paradise park
# Processing Record 11 of Set 1 | waitangi
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | adamstown
# Processing Record 15 of Set 1 | coachella
# Processing Record 16 of Set 1 | okahandja
# Processing Record 17 of Set 1 | bilibino
# Processing Record 18 of Set 1 | udachny
# Processing Record 19 of Set 1 | garhi khairo
# Processing Record 20 of Set 1 | west island
# Processing Record 21 of Set 1 | lebu
# Processing Record 22 of Set 1 | ribeira grande
# Processing Record 23 of Set 1 | morondava
# Processing Record 24 of Set 1 | fortaleza
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | brak
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | port lincoln
# Processing Record 29 of Set 1 | port shepstone
# Processing Record 30 of Set 1 | badger
# Processing Record 31 of Set 1 | laminusa
# Processing Record 32 of Set 1 | batu gajah
# Processing Record 33 of Set 1 | aykhal
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | san antonio
# Processing Record 36 of Set 1 | port elizabeth
# Processing Record 37 of Set 1 | kendari
# Processing Record 38 of Set 1 | cedeira
# Processing Record 39 of Set 1 | baud
# Processing Record 40 of Set 1 | bethel
# Processing Record 41 of Set 1 | gueltat zemmour
# City not found. Skipping...
# Processing Record 42 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 43 of Set 1 | ilulissat
# Processing Record 44 of Set 1 | blackmans bay
# Processing Record 45 of Set 1 | alesund
# Processing Record 46 of Set 1 | sosnovo-ozerskoye
# Processing Record 47 of Set 1 | anadyr
# Processing Record 48 of Set 1 | abadeh
# Processing Record 49 of Set 1 | san jose del guaviare
# Processing Record 50 of Set 1 | kodiak
# Processing Record 0 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 1 of Set 2 | launceston
# Processing Record 2 of Set 2 | vorgashor
# Processing Record 3 of Set 2 | college
# Processing Record 4 of Set 2 | mata-utu
# Processing Record 5 of Set 2 | afaahiti
# Processing Record 6 of Set 2 | fada
# Processing Record 7 of Set 2 | gapyeong
# Processing Record 1 of Set 5 | presidente venceslau
# Processing Record 2 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 3 of Set 5 | acarau
# Processing Record 4 of Set 5 | papao
# Processing Record 5 of Set 5 | maridi
# Processing Record 6 of Set 5 | tadine
# Processing Record 7 of Set 5 | saipan
# Processing Record 8 of Set 5 | prata
# Processing Record 9 of Set 5 | rundu
# Processing Record 10 of Set 5 | ampanihy
# Processing Record 11 of Set 5 | linares
# Processing Record 12 of Set 5 | lakheri
# Processing Record 13 of Set 5 | tangalle
# Processing Record 14 of Set 5 | chulakkurgan
# Processing Record 15 of Set 5 | bela vista do paraiso
# Processing Record 16 of Set 5 | torres
# Processing Record 17 of Set 5 | vadso
# Processing Record 18 of Set 5 | i-n-salah
# Processing Record 19 of Set 5 | whitehorse
# Processing Record 20 of Set 5 | zhezqazghan
# Processing Record 21 of Set 5 | tommot
# Processing Record 22 of Set 5 | mossel bay
# Processing Record 23 of Set 5 | olyokminsk
# Processing Record 24 of Set 5 | vernon
# Processing Record 25 of Set 5 | nuku'alofa
# Processing Record 26 of Set 5 | rubio
# Processing Record 27 of Set 5 | hauterive
# Processing Record 28 of Set 5 | quellon
# Processing Record 29 of Set 5 | tupaciguara
# Processing Record 30 of Set 5 | kristiansund
# Processing Record 31 of Set 5 | invercargill
# Processing Record 32 of Set 5 | bull savanna
# Processing Record 33 of Set 5 | padang
# Processing Record 34 of Set 5 | lyantonde
# Processing Record 35 of Set 5 | huangmei
# Processing Record 36 of Set 5 | chust
# Processing Record 37 of Set 5 | san luis de la loma
# Processing Record 38 of Set 5 | aasiaat
# Processing Record 39 of Set 5 | penzance
# Processing Record 40 of Set 5 | iskateley
# Processing Record 41 of Set 5 | isafjordur
# Processing Record 42 of Set 5 | saudarkrokur
# Processing Record 43 of Set 5 | takamaka
# City not found. Skipping...
# Processing Record 44 of Set 5 | binhe
# Processing Record 45 of Set 5 | nemuro
# Processing Record 46 of Set 5 | tobol
# Processing Record 47 of Set 5 | dunda
# Processing Record 48 of Set 5 | tegueste
# Processing Record 49 of Set 5 | bagrationovsk
# Processing Record 0 of Set 6 | rio grande
# Processing Record 1 of Set 6 | ballina
# Processing Record 2 of Set 6 | coquimbo
# Processing Record 3 of Set 6 | san rafael del sur
# Processing Record 4 of Set 6 | novodvinsk
# Processing Record 5 of Set 6 | hilo
# Processing Record 6 of Set 6 | lompoc
# Processing Record 7 of Set 6 | guiyang
# Processing Record 8 of Set 6 | keyser
# Processing Record 9 of Set 6 | palmer
# Processing Record 10 of Set 6 | serenje
# Processing Record 11 of Set 6 | palikir - national government center
# Processing Record 12 of Set 6 | ngaoundere
# Processing Record 13 of Set 6 | lata
# Processing Record 14 of Set 6 | sarmiento
# Processing Record 15 of Set 6 | naldurg
# Processing Record 16 of Set 6 | kayangel
# Processing Record 17 of Set 6 | hayma'
# City not found. Skipping...
# Processing Record 18 of Set 6 | as sulayyil
# Processing Record 19 of Set 6 | el calafate
# Processing Record 20 of Set 6 | selfoss
# Processing Record 21 of Set 6 | paradip garh
# Processing Record 22 of Set 6 | salinas
# Processing Record 23 of Set 6 | zhangatas
# Processing Record 24 of Set 6 | nova sintra
# Processing Record 25 of Set 6 | mount isa
# Processing Record 26 of Set 6 | fisterra
# Processing Record 27 of Set 6 | villa de arriaga
# City not found. Skipping...
# Processing Record 28 of Set 6 | kingston
# Processing Record 29 of Set 6 | la sarre
# Processing Record 30 of Set 6 | semenivka
# Processing Record 31 of Set 6 | costa teguise
# City not found. Skipping...
# Processing Record 32 of Set 6 | dunedin
# Processing Record 33 of Set 6 | mitu
# Processing Record 34 of Set 6 | enewetak
# Processing Record 35 of Set 6 | stepnogorsk
# Processing Record 36 of Set 6 | ad dawadimi
# Processing Record 37 of Set 6 | tralee
# Processing Record 38 of Set 6 | esmeralda
# Processing Record 39 of Set 6 | al qadarif
# Processing Record 40 of Set 6 | kerikeri
# Processing Record 41 of Set 6 | joroinen
# Processing Record 42 of Set 6 | macau
# Processing Record 43 of Set 6 | itoman
# Processing Record 44 of Set 6 | tolanaro
# Processing Record 45 of Set 6 | labytnangi
# Processing Record 46 of Set 6 | constantia
# Processing Record 47 of Set 6 | sumbawanga
# Processing Record 48 of Set 6 | esperantina
# Processing Record 49 of Set 6 | altai
# Processing Record 0 of Set 7 | mascote
# Processing Record 1 of Set 7 | nantucket
# Processing Record 2 of Set 7 | qaqortoq
# Processing Record 3 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 4 of Set 7 | jamestown
# Processing Record 5 of Set 7 | port saint john's
# Processing Record 6 of Set 7 | uaboe
# City not found. Skipping...
# Processing Record 7 of Set 7 | ves'yegonsk
# Processing Record 8 of Set 7 | lodja
# Processing Record 9 of Set 7 | ballito
# Processing Record 10 of Set 7 | touros
# Processing Record 11 of Set 7 | jiuquan
# Processing Record 12 of Set 7 | qaisumah
# Processing Record 13 of Set 7 | miyanoura
# City not found. Skipping...
# Processing Record 14 of Set 7 | antipino
# Processing Record 15 of Set 7 | al burayqah
# Processing Record 16 of Set 7 | kayyerkan
# Processing Record 17 of Set 7 | ostersund
# Processing Record 18 of Set 7 | bang saphan
# Processing Record 19 of Set 7 | ilomantsi
# Processing Record 20 of Set 7 | codrington
# Processing Record 21 of Set 7 | qoryooley
# Processing Record 22 of Set 7 | alakurtti
# Processing Record 23 of Set 7 | port glaud
# City not found. Skipping...
# Processing Record 24 of Set 7 | port augusta
# Processing Record 25 of Set 7 | kaiapoi
# Processing Record 26 of Set 7 | souillac
# Processing Record 27 of Set 7 | arno
# Processing Record 28 of Set 7 | bakal
# Processing Record 29 of Set 7 | lensk
# Processing Record 30 of Set 7 | nar'yan-mar
# Processing Record 31 of Set 7 | santa maria del oro
# Processing Record 32 of Set 7 | chala
# Processing Record 33 of Set 7 | okha
# Processing Record 34 of Set 7 | mejit
# Processing Record 35 of Set 7 | sungailiat
# Processing Record 36 of Set 7 | ain sefra
# Processing Record 37 of Set 7 | comodoro rivadavia
# Processing Record 38 of Set 7 | muynoq
# Processing Record 39 of Set 7 | koani
# Processing Record 40 of Set 7 | jieshi
# Processing Record 41 of Set 7 | natal
# Processing Record 42 of Set 7 | quemado de guines
# Processing Record 14 of Set 9 | kabba
# Processing Record 15 of Set 9 | weno
# Processing Record 16 of Set 9 | homa bay
# Processing Record 17 of Set 9 | aroma
# Processing Record 18 of Set 9 | mohr
# Processing Record 19 of Set 9 | navrongo
# Processing Record 20 of Set 9 | kill devil hills
# Processing Record 21 of Set 9 | bhisho
# Processing Record 22 of Set 9 | melchor de mencos
# Processing Record 23 of Set 9 | perryville
# Processing Record 24 of Set 9 | yingkou
# Processing Record 25 of Set 9 | bardai
# Processing Record 26 of Set 9 | mar del plata
# Processing Record 27 of Set 9 | smara
# Processing Record 28 of Set 9 | emerald
# Processing Record 29 of Set 9 | korla
# Processing Record 30 of Set 9 | island harbour
# Processing Record 31 of Set 9 | mukalla
# Processing Record 32 of Set 9 | tual
# Processing Record 33 of Set 9 | sidi khaled
# Processing Record 34 of Set 9 | chernyshevskiy
# Processing Record 35 of Set 9 | greymouth
# Processing Record 36 of Set 9 | pacific grove
# Processing Record 37 of Set 9 | boa vista
# Processing Record 38 of Set 9 | fort st. john
# Processing Record 39 of Set 9 | zaragoza
# Processing Record 40 of Set 9 | maxixe
# Processing Record 41 of Set 9 | don luan
# Processing Record 42 of Set 9 | smirnykh
# Processing Record 43 of Set 9 | rongelap
# Processing Record 44 of Set 9 | quibala
# Processing Record 45 of Set 9 | alaior
# Processing Record 46 of Set 9 | saint-hubert
# Processing Record 47 of Set 9 | yolombo
# Processing Record 48 of Set 9 | cambria
# Processing Record 49 of Set 9 | trindade
# Processing Record 0 of Set 10 | fuvahmulah
# City not found. Skipping...
# Processing Record 1 of Set 10 | al 'aziziyah
# Processing Record 2 of Set 10 | grosse pointe farms
# Processing Record 3 of Set 10 | la passe
# Processing Record 4 of Set 10 | lagunas
# Processing Record 5 of Set 10 | jam sahib
# Processing Record 6 of Set 10 | fort mcmurray
# Processing Record 7 of Set 10 | san patricio
# Processing Record 8 of Set 10 | tynda
# Processing Record 9 of Set 10 | buta
# Processing Record 10 of Set 10 | labasa
# Processing Record 11 of Set 10 | khandyga
# Processing Record 12 of Set 10 | tougan
# Processing Record 13 of Set 10 | suva
# Processing Record 14 of Set 10 | santa elena de uairen
# Processing Record 15 of Set 10 | crown point
# Processing Record 16 of Set 10 | mili
# Processing Record 17 of Set 10 | tuapse
# Processing Record 18 of Set 10 | srandakan
# Processing Record 19 of Set 10 | sterling
# Processing Record 20 of Set 10 | borzya
# Processing Record 21 of Set 10 | arraial do cabo
# Processing Record 22 of Set 10 | banda aceh
# Processing Record 23 of Set 10 | inhambane
# Processing Record 24 of Set 10 | katsuren-haebaru
# Processing Record 25 of Set 10 | ciutadella
# Processing Record 26 of Set 10 | amasra
# Processing Record 27 of Set 10 | pamandzi
# Processing Record 28 of Set 10 | spa
# Processing Record 29 of Set 10 | chanika
# Processing Record 30 of Set 10 | glendale
# Processing Record 31 of Set 10 | kananga
# Processing Record 32 of Set 10 | mokopane
# Processing Record 33 of Set 10 | tura
# Processing Record 34 of Set 10 | dhamar
# Processing Record 35 of Set 10 | forde
# Processing Record 36 of Set 10 | shakhan
# Processing Record 37 of Set 10 | ciudad lazaro cardenas
# Processing Record 38 of Set 10 | rahimah
# Processing Record 39 of Set 10 | toga village
# City not found. Skipping...
# Processing Record 40 of Set 10 | gebeit
# Processing Record 41 of Set 10 | uyskoye
# Processing Record 42 of Set 10 | stettler
# Processing Record 43 of Set 10 | port alfred
# Processing Record 44 of Set 10 | hasaki
# Processing Record 45 of Set 10 | kavieng
# Processing Record 46 of Set 10 | margate
# Processing Record 47 of Set 10 | pitimbu
# Processing Record 48 of Set 10 | lazaro cardenas
# Processing Record 49 of Set 10 | porto novo
# Processing Record 0 of Set 11 | tosontsengel
# Processing Record 1 of Set 11 | batticaloa
# Processing Record 2 of Set 11 | antalaha
# Processing Record 3 of Set 11 | neryungri
# Processing Record 4 of Set 11 | villa dolores
# Processing Record 5 of Set 11 | puerto maldonado
# Processing Record 6 of Set 11 | beira
# Processing Record 7 of Set 11 | nelson bay
# Processing Record 8 of Set 11 | kapit
# Processing Record 9 of Set 11 | acs
# Processing Record 10 of Set 11 | araguaina
# Processing Record 11 of Set 11 | hobe sound
# Processing Record 12 of Set 11 | garoowe
# Processing Record 13 of Set 11 | twon-brass
# Processing Record 14 of Set 11 | nadym
# Processing Record 15 of Set 11 | beyneu
# Processing Record 16 of Set 11 | lerwick
# Processing Record 17 of Set 11 | kapa'a
# Processing Record 18 of Set 11 | nadvoitsy
# Processing Record 19 of Set 11 | east london
# Processing Record 20 of Set 11 | newman
# Processing Record 21 of Set 11 | chibougamau
# Processing Record 22 of Set 11 | vilyuchinsk
# Processing Record 23 of Set 11 | ambodifotatra
# Processing Record 24 of Set 11 | duba
# Processing Record 25 of Set 11 | brockville
# Processing Record 26 of Set 11 | battagram
# Processing Record 27 of Set 11 | masterton
# Processing Record 28 of Set 11 | guaratuba
# Processing Record 29 of Set 11 | laascaanood
# Processing Record 30 of Set 11 | nyandoma
# Processing Record 31 of Set 11 | chaves
# Processing Record 32 of Set 11 | minas de marcona
# Processing Record 33 of Set 11 | mccomb
# Processing Record 34 of Set 11 | villa huidobro
# Processing Record 35 of Set 11 | nebraska city
# Processing Record 36 of Set 11 | luis correia
# Processing Record 37 of Set 11 | saint-denis
# Processing Record 38 of Set 11 | quincy
# Processing Record 39 of Set 11 | ancud
# Processing Record 40 of Set 11 | east ballina
# Processing Record 41 of Set 11 | fort bragg
# Processing Record 42 of Set 11 | rakops
# Processing Record 43 of Set 11 | princeville
# Processing Record 44 of Set 11 | gordonvale
# Processing Record 45 of Set 11 | sechura
# Processing Record 46 of Set 11 | debre birhan
# Processing Record 47 of Set 11 | heroica caborca
# Processing Record 48 of Set 11 | neiafu
# Processing Record 49 of Set 11 | tabou
# Processing Record 0 of Set 12 | tasqala
# Processing Record 1 of Set 12 | cidade velha
# Processing Record 2 of Set 12 | kamiiso
# Processing Record 3 of Set 12 | sitka
# Processing Record 4 of Set 12 | la'ie
# Processing Record 5 of Set 12 | santyoku
# Processing Record 6 of Set 12 | chegdomyn
# Processing Record 7 of Set 12 | nuuk
# Processing Record 8 of Set 12 | kencong
# Processing Record 9 of Set 12 | pandan
# Processing Record 10 of Set 12 | carauari
# Processing Record 11 of Set 12 | port moresby
# Processing Record 12 of Set 12 | yar
# Processing Record 13 of Set 12 | makurazaki
# Processing Record 14 of Set 12 | aiquile
# Processing Record 15 of Set 12 | yamba
# Processing Record 16 of Set 12 | kargasok
# Processing Record 17 of Set 12 | petra-dubrava
# Processing Record 18 of Set 12 | toliara
# Processing Record 19 of Set 12 | glace bay
# Processing Record 20 of Set 12 | polyarnyy
# Processing Record 21 of Set 12 | usogorsk
# Processing Record 22 of Set 12 | bechar
# Processing Record 23 of Set 12 | morant bay
# Processing Record 24 of Set 12 | collingwood
# Processing Record 25 of Set 12 | halifax
# Processing Record 26 of Set 12 | palembang
# Processing Record 27 of Set 12 | carinhanha
# Processing Record 28 of Set 12 | mabaruma
# Processing Record 29 of Set 12 | fulton
# Processing Record 30 of Set 12 | bikenibeu village
# Processing Record 31 of Set 12 | xilin hot
# Processing Record 32 of Set 12 | san carlos de bariloche
# Processing Record 33 of Set 12 | middelburg
# Processing Record 34 of Set 12 | leava
# Processing Record 35 of Set 12 | oroshaza
# Processing Record 36 of Set 12 | mabini
# Processing Record 37 of Set 12 | mamadysh
# Processing Record 38 of Set 12 | richards bay
# Processing Record 39 of Set 12 | pitkyaranta
# Processing Record 40 of Set 12 | sfax
# Processing Record 41 of Set 12 | saint-francois
# Processing Record 42 of Set 12 | nuevitas
# Processing Record 43 of Set 12 | naze
# Processing Record 44 of Set 12 | mahenge
# Processing Record 45 of Set 12 | harnai
# Processing Record 46 of Set 12 | suamico
# Processing Record 47 of Set 12 | krasnaya gorbatka
# Processing Record 48 of Set 12 | gabu
# Processing Record 49 of Set 12 | wuzhou
# Processing Record 0 of Set 13 | muisne
# Processing Record 1 of Set 13 | skovorodino
# Processing Record 2 of Set 13 | kone
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data,columns=["City",
                                             "Lat",
                                             "Lng",
                                             "Max Temp",
                                             "Humidity",
                                             "Cloudiness",
                                             "Wind Speed",
                                             "Country",
                                             "Date"])

# Show Record Count
city_data_df.count()
# Out:
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       577
# Date          577
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167      5.55        67          23
# 1         giovinazzo  41.1864   16.6674     17.95        56           0
# 2              tofol   5.3248  163.0078     25.88        89         100
# 3     puerto natales -51.7236  -72.4875      4.12        96         100
# 4           karratha -20.7377  116.8463     32.24        31         100
#
#    Wind Speed Country        Date
# 0       10.87      TF  1682664050
# 1        1.54      IT  1682664051
# 2        1.54      FM  1682664051
# 3        0.53      CL  1682664051
# 4        4.54      AU  1682664053

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      5.55        67          23
# 1               giovinazzo  41.1864   16.6674     17.95        56           0
# 2                    tofol   5.3248  163.0078     25.88        89         100
# 3           puerto natales -51.7236  -72.4875      4.12        96         100
# 4                 karratha -20.7377  116.8463     32.24        31         100
#
#          Wind Speed Country        Date
# City_ID
# 0             10.87      TF  1682664050
# 1              1.54      IT  1682664051
# 2              1.54      FM  1682664051
# 3              0.53      CL  1682664051
# 4              4.54      AU  1682664053

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude VS Temperature for Cities")
plt.ylabel("Max Temperature")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Lat.vs.Temp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude VS Humidity for Cities")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Lat.vs.Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude VS Cloudiness for Cities")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Lat.vs.Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude VS Wind Speed for Cities")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Lat.vs.WindSpeed.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = linregress(X, Y)
regress_values = X * slope + intercept

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df[city_data_df["Lat"]>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                    giovinazzo  41.1864   16.6674     17.95        56
# 2                         tofol   5.3248  163.0078     25.88        89
# 6                        albany  42.6001  -73.9662      7.07        88
# 9        hawaiian paradise park  19.5933 -154.9731     23.73        91
# 12                   georgetown   5.4112  100.3354     31.97        70
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                 0        1.54      IT  1682664051
# 2               100        1.54      FM  1682664051
# 6                67        0.43      US  1682664053
# 9               100        2.06      US  1682664054
# 12               20        4.63      MY  1682664055

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df[city_data_df["Lat"]<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      5.55        67          23
# 3           puerto natales -51.7236  -72.4875      4.12        96         100
# 4                 karratha -20.7377  116.8463     32.24        31         100
# 5                   vanimo  -2.6741  141.3028     28.52        78          86
# 7            port mathurin -19.6833   63.4167     26.17        80          22
#
#          Wind Speed Country        Date
# City_ID
# 0             10.87      TF  1682664050
# 3              0.53      CL  1682664051
# 4              4.54      AU  1682664053
# 5              2.08      PG  1682664053
# 7              7.52      MU  1682664053

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
regress_values = northern_hemi_df["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], marker="o")
plt.plot((northern_hemi_df["Lat"]),regress_values,"r-")

plt.title("Latitude VS Temperature for Northern Cities")
plt.ylabel("Max Temperature")
plt.xlabel("Latitude")
plt.annotate(line_eq,(10,-10),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# y = -0.46x +32.92
# The r-value is: 0.6870291841881216

# %%
# Linear regression on Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
regress_values = southern_hemi_df["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"], marker="o")
plt.plot((southern_hemi_df["Lat"]),regress_values,"r-")

plt.title("Latitude VS Temperature for Southern Cities")
plt.ylabel("Max Temperature")
plt.xlabel("Latitude")
plt.annotate(line_eq,(-50,30),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# y = 0.36x +29.15
# The r-value is: 0.5807355020463528

# %% [markdown]
# **Discussion about the linear relationship:**
# Northern Cities: The Northern Cities Plot has a Strong, Negative Correlation. As the Latitude increases the Maximum Temperature decreases.
#
# Southern Cities: The Northern Cities Plot has a Moderate, Positive Correlation. As the Latitude increases the Maximum Temperature also increases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
regress_values = northern_hemi_df["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], marker="o")
plt.plot((northern_hemi_df["Lat"]),regress_values,"r-")

plt.title("Latitude VS Humidity for Cities")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.annotate(line_eq,(45,5),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# y = 0.05x +65.35
# The r-value is: 0.001753579527797325

# %%
# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
regress_values = southern_hemi_df["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], marker="o")
plt.plot((southern_hemi_df["Lat"]),regress_values,"r-")

plt.title("Latitude VS Humidity for Cities")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# y = 0.14x +77.74
# The r-value is: 0.01307508896420993

# %% [markdown]
# **Discussion about the linear relationship:**
# Northern Cities: From the plot, it seems as though there is either no correlation, or at least a very weak correlation. It is also very difficult to verify if there is a positive or negative correlation on first glance, but when looking at specifically the line and the equation, it seems there is a very weak positive correlation.
#
# Southern Cities: From the plot, it seems as though there is either no correlation, or at least a very weak correlation. It is  very difficult to verify if there is a positive or negative correlation on first glance, but when looking at specifically the line and the equation, it seems there is a very weak positive correlation.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
regress_values = northern_hemi_df["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], marker="o")
plt.plot((northern_hemi_df["Lat"]),regress_values,"r-")

plt.title("Latitude VS Cloudiness for Cities")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.annotate(line_eq,(55,80),fontsize=12,color="red")

print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# y = -0.03x +60.61
# The r-value is: 0.00019451174194245425

# %%
# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
regress_values = southern_hemi_df["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], marker="o")
plt.plot((southern_hemi_df["Lat"]),regress_values,"r-")

plt.title("Latitude VS Cloudiness for Cities")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.annotate(line_eq,(-55,60),fontsize=12,color="red")

print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# y = 0.64x +66.25
# The r-value is: 0.05344654103594599

# %% [markdown]
# **Discussion about the linear relationship:**
# Northern Cities:  From the plot, it seems as though there is either no correlation, or at least a very weak correlation. It is  very difficult to verify if there is a positive or negative correlation on first glance, but when looking at specifically the line and the equation, it seems there is a very weak, slightly positive correlation.
#
# Southern Cities:  From the plot, it seems as though there is either no correlation, or at least a very weak correlation. It is  very difficult to verify if there is a positive or negative correlation on first glance, but when looking at specifically the line and the equation, it seems there is a very weak, positive correlation.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
regress_values = northern_hemi_df["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], marker="o")
plt.plot((northern_hemi_df["Lat"]),regress_values,"r-")

plt.title("Latitude VS Cloudiness for Cities")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.annotate(line_eq,(-55,60),fontsize=12,color="red")

print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# y = 0.02x +2.97
# The r-value is: 0.01598077195239958

# %%
# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
regress_values = southern_hemi_df["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], marker="o")
plt.plot((southern_hemi_df["Lat"]),regress_values,"r-")

plt.title("Latitude VS Cloudiness for Cities")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.annotate(line_eq,(-55,60),fontsize=12,color="red")

print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# y = -0.02x +2.62
# The r-value is: 0.0206799342734357

# %% [markdown]
# **Discussion about the linear relationship:**
# Northern Cities:  From the plot, it seems as though there is either no correlation, or at least a very weak correlation. It is  very difficult to verify if there is a positive or negative correlation on first glance, but when looking at specifically the line and the equation, it seems there is a very weak, slightly positive correlation.
#
# Southern Cities:  From the plot, it seems as though there is either no correlation, or at least a very weak correlation. It is  very difficult to verify if there is a positive or negative correlation on first glance, but when looking at specifically the line and the equation, it seems there is a very weak, slightly negative correlation.
